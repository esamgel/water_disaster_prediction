# %%
# necessary for when working with external scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

filename1 = "Datasets\typhoon.xlsx"

typhoon_df = pd.read_excel('typhoon.xlsx', sheet_name='工作表1')

# %%
typhoon_df.tail()
# Out:
#         年份        編號 中文名稱     英文名稱 侵臺路徑分類                警報期間     近臺強度   近臺  \
# 66     NaN       NaN  NaN      NaN    NaN 2012-08-03 14:30:00      NaN  NaN
# 67  2012.0  201206.0  杜蘇芮  DOKSURI    --- 2012-06-28 05:30:00  輕度(low)  995
# 68     NaN       NaN  NaN      NaN    NaN 2012-06-29 08:30:00      NaN  NaN
# 69  2012.0  201205.0   泰利    TALIM      9 2012-06-19 05:30:00  輕度(low)  985
# 70     NaN       NaN  NaN      NaN    NaN 2012-06-21 05:30:00      NaN  NaN
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10  警報發布報數
# 66        NaN        NaN         NaN     NaN
# 67         23        120         ---    10.0
# 68        NaN        NaN         NaN     NaN
# 69         25        150         ---    17.0
# 70        NaN        NaN         NaN     NaN

# %%
import zipfile

zf = zipfile.ZipFile('Datasets\water_level_2012.zip') # having First.csv zipped file.
wl2012_df = pd.read_csv(zf.open('water_level_2012.csv'))

# %%
wl2012_df.tail()
# Out:
#         station_code                   PhysicalQuantity_id  \
# 6926006     1430H061  83c908c6-bd10-4dd5-ab41-dd4f5d59c3f4
# 6926007     1430H061  83c908c6-bd10-4dd5-ab41-dd4f5d59c3f4
# 6926008     1430H061  83c908c6-bd10-4dd5-ab41-dd4f5d59c3f4
# 6926009     1430H061  83c908c6-bd10-4dd5-ab41-dd4f5d59c3f4
# 6926010     1430H061  83c908c6-bd10-4dd5-ab41-dd4f5d59c3f4
#
#                          timestamp  water_level
# 6926006  2012-12-31T23:10:00+08:00        25.08
# 6926007  2012-12-31T23:20:00+08:00        25.08
# 6926008  2012-12-31T23:30:00+08:00        25.07
# 6926009  2012-12-31T23:40:00+08:00        25.08
# 6926010  2012-12-31T23:50:00+08:00        25.08

# %%
zf = zipfile.ZipFile('Datasets\water_level_2013.zip') # having First.csv zipped file.
wl2013_df = pd.read_csv(zf.open('water_level_2013.csv'))

zf = zipfile.ZipFile('Datasets\water_level_2014.zip') # having First.csv zipped file.
wl2014_df = pd.read_csv(zf.open('water_level_2014.csv'))

zf = zipfile.ZipFile('Datasets\water_level_2015.zip') # having First.csv zipped file.
wl2015_df = pd.read_csv(zf.open('water_level_2015.csv'))

zf = zipfile.ZipFile('Datasets\water_level_2016.zip') # having First.csv zipped file.
wl2016_df = pd.read_csv(zf.open('water_level_2016.csv'))

zf = zipfile.ZipFile('Datasets\water_level_2017.zip') # having First.csv zipped file.
wl2017_df = pd.read_csv(zf.open('water_level_2017.csv'))

# %%
zf = zipfile.ZipFile('Datasets\water_level_201801-08.zip') # having First.csv zipped file.
wl201801_08_df = pd.read_csv(zf.open('water_level_201801-08.csv'))

zf = zipfile.ZipFile('Datasets\water_level_201809.zip') # having First.csv zipped file.
wl2018_09_df = pd.read_csv(zf.open('water_level_201809.csv'))

# %%
wl2013_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 1     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 2     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 3     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 4     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
#
#                    timestamp  water_level
# 0  2013-01-01T00:30:00+08:00       198.64
# 1  2013-01-01T00:40:00+08:00       198.64
# 2  2013-01-01T00:50:00+08:00       198.64
# 3  2013-01-01T01:00:00+08:00       198.64
# 4  2013-01-01T01:10:00+08:00       198.63

# %%
wl2014_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 1     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 2     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 3     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 4     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
#
#                    timestamp  water_level
# 0  2014-01-01T00:10:00+08:00       197.70
# 1  2014-01-01T00:20:00+08:00       197.71
# 2  2014-01-01T00:30:00+08:00       197.71
# 3  2014-01-01T00:40:00+08:00       197.71
# 4  2014-01-01T00:50:00+08:00       197.71

# %%
wl2015_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 1     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 2     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 3     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 4     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
#
#                    timestamp  water_level
# 0  2015-01-01T00:30:00+08:00        197.5
# 1  2015-01-01T00:40:00+08:00        197.5
# 2  2015-01-01T00:50:00+08:00        197.5
# 3  2015-01-01T01:00:00+08:00        197.5
# 4  2015-01-01T01:10:00+08:00        197.5

# %%
wl2016_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 1     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 2     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 3     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 4     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
#
#                    timestamp  water_level
# 0  2016-01-01T00:10:00+08:00        197.5
# 1  2016-01-01T00:20:00+08:00        197.5
# 2  2016-01-01T00:30:00+08:00        197.5
# 3  2016-01-01T00:40:00+08:00        197.5
# 4  2016-01-01T00:50:00+08:00        197.5

# %%
wl2017_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 1     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 2     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 3     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
# 4     1420H056  c78e2ec3-b418-4f9c-bb7e-1fff40a5a2e7
#
#                    timestamp  water_level
# 0  2017-01-04T01:40:00+08:00       196.23
# 1  2017-01-04T01:50:00+08:00       196.23
# 2  2017-01-04T02:00:00+08:00       196.23
# 3  2017-01-04T02:10:00+08:00       196.24
# 4  2017-01-04T02:20:00+08:00       196.23

# %%
wl201801_08_df.head()
# Out:
#   station_code                   PhysicalQuantity_id  \
# 0     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 1     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 2     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 3     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 4     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
#
#                    timestamp  water_level
# 0  2018-03-07T13:40:00+08:00         9.95
# 1  2018-03-07T13:50:00+08:00         9.95
# 2  2018-03-07T14:00:00+08:00         9.95
# 3  2018-03-07T14:10:00+08:00         9.95
# 4  2018-03-07T14:20:00+08:00         9.95

# %%
wl2018_09_df.head()
# Out:
#   station_id station_name  water_level          dt_record
# 0   1630H023         麻善大橋         0.73  1/9/2018 00:00:00
# 1   1730H077        達西霸樂橋       740.50  1/9/2018 00:00:00
# 2   1850H004          石門橋        72.69  1/9/2018 00:00:00
# 3   2500H003          希能埔        29.37  1/9/2018 00:00:00
# 4   2200H029          鹿鳴橋       145.97  1/9/2018 00:00:00

# %%
wl2018_09_df.station_id.value_counts()
# Out:
# 1400H015    823
# 1540H029    823
# 1730H075    823
# 1300H023    823
# 1320H002    823
# 1430H060    823
# 1350H025    823
# 1340H010    823
# 1730H062    823
# 1300H024    823
# 1550H016    823
# 1650H014    823
# 1630H037    823
# 1350H017    823
# 1430H048    823
# 1420H049    823
# 2200H022    823
# 1550H012    823
# 1430H055    823
# 1650H010    823
# 1340H013    823
# 1650H006    823
# 1140H068    823
# 1550H018    823
# 1140H108    823
# 1350H024    823
# 1140H066    823
# 1430H038    823
# 1400H018    823
# 1650H015    823
#            ...
# 1290H004    813
# 1510H079    813
# 1510H064    813
# 1510H076    813
# 1510H058    813
# 1510H075    813
# 1510H050    812
# 2560H006    806
# 1140H097    795
# 1140H101    794
# 1140H102    794
# 1140H099    794
# 1140H096    794
# 1140H109    794
# 1140H098    793
# 1540H033    785
# 1430H054    746
# 1740H008    724
# 1140H107    681
# 1630H033    679
# 1630H032    679
# 1630H030    679
# 1630H031    679
# 1630H027    679
# ...

# %%
wl2018_09_df.station_name.value_counts()
# Out:
# 中正橋        1502
# 玉峰橋        1502
# 北寮橋         823
# 觀海大橋        823
# 大窩橋         823
# 中正大橋        823
# 嘉新橋         823
# 雙東大橋        823
# 懷恩橋         823
# 觸口          823
# 溝坪橋         823
# 青葉橋         823
# 仁壽橋         823
# 杉林大橋(2)     823
# 西結橋         823
# 家源橋         823
# 復興橋         823
# 重溪橋         823
# 頭前溪橋        823
# 恭敬橋         823
# 清水溪橋        823
# 福南橋         823
# 口社富邦大橋      823
# 六龜(1)       823
# 順義橋         823
# 柯子湖溪匯流站     823
# 麻魚寮橋        823
# 萬福橋         823
# 象鼻(3)       823
# 官田橋         823
#            ...
# 寶石橋         813
# 龍門橋         813
# 關西          813
# 內茅埔         813
# 西濱大橋        813
# 溪州大橋        813
# 水里          813
# 自強大橋        813
# 延平橋         812
# 蘭陽大橋        806
# 大林橋         795
# 虎寮潭橋站       794
# 屈尺堰         794
# 思源橋         794
# 坪林拱橋站       794
# 水源橋         794
# 金瓜寮橋        793
# 田頭橋         785
# 福新橋         746
# 興社大橋        724
# 安坑橋         681
# 北勢洲         679
# 曾文溪         679
# 走馬瀨         679
# ...

# %%
wl2018_09_df.loc[wl2018_09_df['station_name'] == '玉峰橋']
# Out:
#        station_id station_name  water_level           dt_record
# 114      1510H063          玉峰橋       264.40   1/9/2018 00:20:00
# 203      1630H028          玉峰橋        10.18   1/9/2018 00:20:00
# 262      1630H028          玉峰橋        10.12   1/9/2018 00:50:00
# 413      1510H063          玉峰橋       264.41   1/9/2018 01:00:00
# 510      1630H028          玉峰橋        10.11   1/9/2018 01:20:00
# 618      1510H063          玉峰橋       264.51   1/9/2018 01:30:00
# 854      1510H063          玉峰橋       264.40   1/9/2018 01:50:00
# 994      1630H028          玉峰橋        10.17   1/9/2018 01:50:00
# 1135     1630H028          玉峰橋        10.22   1/9/2018 02:20:00
# 1241     1510H063          玉峰橋       264.34   1/9/2018 02:20:00
# 1382     1510H063          玉峰橋       264.26   1/9/2018 02:50:00
# 1510     1630H028          玉峰橋        10.24   1/9/2018 05:20:00
# 1710     1510H063          玉峰橋       264.48   1/9/2018 05:40:00
# 1764     1630H028          玉峰橋        10.18   1/9/2018 07:20:00
# ...

# %%
#combine all datasets dataframes to 1(df) 

frames = [wl2012_df, wl2013_df, wl2014_df, wl2015_df, wl2016_df, wl2017_df, wl201801_08_df]

wl_df = pd.concat(frames, ignore_index=True)

# %%
wl_df.tail()
# Out:
#          station_code                   PhysicalQuantity_id  \
# 52681378     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 52681379     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 52681380     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 52681381     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
# 52681382     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
#
#                           timestamp  water_level
# 52681378  2018-03-07T12:50:00+08:00         9.95
# 52681379  2018-03-07T13:00:00+08:00         9.95
# 52681380  2018-03-07T13:10:00+08:00         9.95
# 52681381  2018-03-07T13:20:00+08:00         9.95
# 52681382  2018-03-07T13:30:00+08:00         9.95

# %% [markdown]
# # Example of select column with condition below:

# %% [markdown]
# To select rows whose column value equals a scalar, some_value, use ==:
#
# df.loc[df['column_name'] == some_value]
#
# To select rows whose column value is in an iterable, some_values, use isin:
#
# df.loc[df['column_name'].isin(some_values)]
#
# Combine multiple conditions with &:
#
# df.loc[(df['column_name'] == some_value) & df['other_column'].isin(some_values)]

# %%
wl_df.loc[(wl_df['timestamp'] == '2018-03-07T12:50:00+08:00') & (wl_df['station_code'] == '1580H013')]
# Out:
#          station_code                   PhysicalQuantity_id  \
# 52681378     1580H013  1b6703d7-1d2c-44db-8f3c-5ecac70db35c
#
#                           timestamp  water_level
# 52681378  2018-03-07T12:50:00+08:00         9.95

# %%
typhoon_df.head()
# Out:
#        年份        編號 中文名稱      英文名稱 侵臺路徑分類                警報期間        近臺強度  \
# 0     NaN       NaN  NaN       NaN    NaN                 NaT         NaN
# 1  2018.0  201822.0   山竹  MANGKHUT    --- 2018-09-14 11:30:00  強烈(Strong)
# 2     NaN       NaN  NaN       NaN    NaN 2018-09-15 20:30:00         NaN
# 3  2018.0  201808.0  瑪莉亞     MARIA    --- 2018-07-09 14:30:00  強烈(Strong)
# 4     NaN       NaN  NaN       NaN    NaN 2018-07-11 14:30:00         NaN
#
#           近臺 Unnamed: 8   Unnamed: 9   Unnamed: 10  警報發布報數
# 0  最低氣壓(hPa)  最大風速(m/s)  7級風暴風半徑(km)  10級風暴風半徑(km)     NaN
# 1        895         60          320           120    12.0
# 2        NaN        NaN          NaN           NaN     NaN
# 3        915         55          280           100    17.0
# 4        NaN        NaN          NaN           NaN     NaN

# %%
wl_df.loc[(wl_df['timestamp'] == '2018-09-14 11:30:00') & wl_df['timestamp'] == '2018-09-15 20:30:00')]
# Out:
#   File "<ipython-input-118-34c6fd858219>", line 1
#     wl_df.loc[(wl_df['警報期間'] == '2018-09-14 11:30:00') & wl_df['timestamp'] == '2018-09-15 20:30:00')]
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
tsty=typhoon_df.loc[typhoon_df['警報期間'] == '2018-09-14 11:30:00']

# %%
ts1 = tsty.iloc[0]['警報期間']

# %%
tsT= pd.to_datetime(ts1, unit='s', utc=True)

# %%
tswl=wl_df.loc[wl_df['timestamp'] == '2018-03-07T12:50:00+08:00']

# %%
ts2 = tswl.iloc[0]['timestamp']

# %%
import dateutil.parser
ts2_normal = dateutil.parser.parse(ts2)

# %%
print (ts2_normal)
# Out:
# 2018-03-07 12:50:00+08:00

# %%
tsW = pd.to_datetime(ts2_normal, utc=True)

# %%
if tsW == tsT:
    print ('ok')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-e2eef349a460> in <module>()
# ----> 1 if tsW == tsT:
#       2     print ('ok')
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__richcmp__()
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp._assert_tzawareness_compat()
#
# TypeError: Cannot compare tz-naive and tz-aware timestamps
